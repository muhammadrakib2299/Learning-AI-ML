# %%
raining = False
muddy = True

if raining == True: 
    print("Rain coat is necessary")
    if muddy == True:
        print("Sandal is necessary")
    else:
        print("Bring Sneakers")
else:
    print("Go without rain coat")
    print("This is a sunny day")
# Out:
# Go without rain coat
# This is a sunny day

# %%
taka = 1000

## 500 er beshi hole gurte jabo
## 400 er beshi hole bashai kisu ekta order korbo
## er kom thak savings
