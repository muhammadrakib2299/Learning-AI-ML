# %%
phone_number = 5968535245
print(phone_number)
# Out:
# 5968535245

# %%
name = 'Rakib'
print(name)
# Out:
# Rakib

# %% [markdown]
# Taking Input in Python

# %%
name = input('What is your name ?')

print(name)
# Out:
# phitron

# %%
age = input("Age ?")

print(age, type(age))
# Out:
# 30 <class 'str'>

# %%
height = float(input("Height ?"))

print(height, type(height))
# Out:
# 3.6 <class 'float'>
