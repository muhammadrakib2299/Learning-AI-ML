# %%
x = 10; y = 15

sum = x + y # summation
sub = x - y # subtraction
mult = x * y # multipication
div = round(x / y , 2)  # division

rem = x % y # reminder 

print(sum, sub, mult, div, rem)
# Out:
# 25 -5 150 0.67 10

# %%
x = 10; y = 30

greater = x > y 

greater_equal = 10 >= 10

print(greater, greater_equal)
# Out:
# False True
