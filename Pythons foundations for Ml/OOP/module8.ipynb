# %%
class Phone: 
    category = 'Electronics'

    def __init__(self, model, battery, camera):
        self.model = model
        self.battery = battery
        self.camera = camera

# %%
## creating a object
apple = Phone('iphone 17 pro', 3000, 40)
print(apple)
print(apple.category)
# Out:
# ...
# Electronics
